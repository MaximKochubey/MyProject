# %% [markdown]
# <a href="https://colab.research.google.com/github/MaximKochubey/MyProject/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
0.3 + 0.3
# Out:
# 0.6
